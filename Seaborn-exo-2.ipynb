# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
data_sp = pd.read_csv('../../data/sales_predictions.csv')

# %%
sp = sns.relplot(x='item_price', y='date', data=data_sp);sp

# %%
data_sp = pd.DataFrame(data_sp);
data_sp = data_sp.sample(n=50); data_sp
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2766361  18.07.2015              30       31    11188      359.00
# 1687166  27.05.2014              16       39     2737      199.00
# 1525430  27.03.2014              14       31    17958      699.00
# 2725757  04.07.2015              30       15    12440      332.00
# 2084994  29.10.2014              21       52     7070      299.50
# 1127897  19.12.2013              11       25    14818      199.00
# 198642   23.02.2013               1       45     3328      999.50
# 1116006  10.11.2013              10       51    21918      245.00
# 156671   17.02.2013               1       24     4248     1999.00
# 2075083  04.10.2014              21       57     4910      419.00
# 1415808  25.02.2014              13       16     5573      499.00
# 2817716  24.08.2015              31       28    15112      159.00
# 153776   10.02.2013               1       23     1122      299.00
# ...

# %%
sp2 = sns.relplot(x='item_price', y='date', data=data_sp, height=20);sp2

# %%
date_time=pd.to_datetime(data_sp['date'], format='%d.%m.%Y');
data_sp['date'] = date_time;
time = date_time.sample(n=50); time
# Out:
# 531323    2013-05-29
# 2781858   2015-08-08
# 52629     2013-01-07
# 1922079   2014-08-25
# 1631268   2014-05-07
# 2390413   2015-01-31
# 2281863   2014-12-29
# 450464    2013-05-15
# 381855    2013-04-28
# 1208449   2013-12-05
# 2687714   2015-06-24
# 544851    2013-06-15
# 1334431   2014-01-04
# 1149677   2013-12-21
# 2075083   2014-10-04
# 1525430   2014-03-27
# 1331862   2014-01-28
# 1622081   2014-04-19
# 2725757   2015-07-04
# 2572197   2015-04-24
# 1116006   2013-11-10
# 2084994   2014-10-29
# 1642932   2014-05-16
# 153776    2013-02-10
# 1549093   2014-03-22
# 2354916   2015-01-27
# 17779     2013-01-20
# 131616    2013-02-02
# 2817716   2015-08-24
# 156671    2013-02-17
# 2671800   2015-06-19
# 2766361   2015-07-18
# 1616791   2014-04-03
# 579920    2013-06-16
# 1018301   2013-10-03
# 971706    2013-10-09
# 1652252   2014-05-07
# 120805    2013-02-24
# 2774296   2015-07-11
# 740868    2013-08-31
# 578852    2013-06-13
# 754420    2013-08-08
# 1452238   2014-02-02
# ...

# %%
sp3 = sns.relplot(x='item_price', y='date', data=data_sp, height=20);sp3
